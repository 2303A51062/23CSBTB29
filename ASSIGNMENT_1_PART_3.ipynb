# %% [markdown]
# <a href="https://colab.research.google.com/github/2303A51062/23CSBTB29/blob/main/ASSIGNMENT_1_PART_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
data=pd.read_excel("/content/aiml_a1_part3.xlsx")
print(data)
df=pd.DataFrame(data,columns=["STUDENT ID"])
df
# Out:
#      SID       HT.NO        S.NAME  AGE  COURSE  BATCH.NO     CELL.NO
# 0   2000  2303A51416          NANI   20  B.TECH        29  7995772623
# 1   2001  2303A51474          Anna   19  B.TECH        29  7657687986
# 2   2002   2303A5121      Bhargavi   20  B.TECH        29  5787398090
# 3   2003   2303A5122         Bisma   23  B.TECH        29  4475799007
# 4   2004   2303A5123  Chandralekha   21  B.TECH        29  5675678755
# 5   2005   2303A5134         Feral   24  B.TECH        29  6768984790
# 6   2006   2303A5135        Devika   18  B.TECH        29  6557646787
# 7   2007   2303A5136          Esha   19  B.TECH        29  8667457646
# 8   2008   2303A5137         Ganga   19  B.TECH        29  7476784756
# 9   2009   2303A5138       Genelia   20  B.TECH        29  2565745646
# 10  2010   2303A5139        Harini   19  B.TECH        29  6847889656
# 11  2011   2303A5140        Indira   20  B.TECH        29  7876668668
# ...

# %%
import pandas as pd
data=pd.read_csv("/content/heart[1].csv")
print(data)
df=pd.DataFrame(data,columns=("age","chol"))
df
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 0         2   2     3       0
# ...

# %%
import pandas as pd
data=pd.read_csv("/content/games_dataset.csv")
print(data)
df=pd.DataFrame(data,columns=("Game Name","Genre"))
df
# Out:
#                                     Game Name       Genre         Platform  \
# 0                   Sekiro: Shadows Die Twice      Sports  Nintendo Switch
# 1                                     Control      Puzzle  Nintendo Switch
# 2                                    Among Us    Strategy  Nintendo Switch
# 3                Call of Duty: Modern Warfare     Stealth      PlayStation
# 4                           League of Legends  Simulation               PC
# ...                                       ...         ...              ...
# 4995  The Legend of Zelda: Breath of the Wild      Sports               PC
# 4996                Assassin's Creed Valhalla     Stealth           Mobile
# 4997             Fall Guys: Ultimate Knockout      Sports           Mobile
# 4998                            Borderlands 3  Platformer             Xbox
# 4999         Counter-Strike: Global Offensive      Action      PlayStation
#
#       Release Year  User Rating
# 0             2014     9.654719
# ...
